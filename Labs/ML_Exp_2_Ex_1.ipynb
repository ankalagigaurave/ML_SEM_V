# %% [markdown]
# <a href="https://colab.research.google.com/github/ankalagigaurave/ML_SEM_V/blob/master/Labs/ML_Exp_2_Ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercise 1

# %%
filename = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
 "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
 "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
 "peak-rpm","city-mpg","highway-mpg","price"]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# To read data

# %%
auto=pd.read_csv(filename,names=headers)
auto
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %% [markdown]
# Replacing illegal values

# %%
auto.replace("?",np.nan,inplace=True)
auto
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3               NaN  alfa-romero  ...       21          27  13495
# 1            3               NaN  alfa-romero  ...       21          27  16500
# 2            1               NaN  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %% [markdown]
# Finding out number of null values in each column

# %%
auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Droping rows which have null values for column 'price'

# %%
auto.dropna(how='any',subset=["price"],inplace=True)
auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %% [markdown]
# Replacing null values in a column with mean of that column

# %%
auto['normalized-losses'].replace(np.nan,value=auto['normalized-losses'].astype('float').mean(),inplace=True)
auto['normalized-losses'].isnull().sum()
# Out:
# 0

# %%
auto['bore'].replace(np.nan,value=auto['bore'].astype('float').mean(),inplace=True)
auto['stroke'].replace(np.nan,value=auto['stroke'].astype('float').mean(),inplace=True)
auto['horsepower'].replace(np.nan,value=auto['horsepower'].astype('float').mean(),inplace=True)
auto['peak-rpm'].replace(np.nan,value=auto['peak-rpm'].astype('float').mean(),inplace=True)
auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# Replacing null values in the column with mode of that column

# %%
mode1=auto['num-of-doors'].mode()


auto['num-of-doors'].replace(np.nan,value=mode1[0],inplace=True)
auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
type(auto['num-of-doors'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Resetting the index of the dataframe

# %%
auto=auto.reset_index()

# %%
auto
# Out:
#      index  symboling normalized-losses  ... city-mpg highway-mpg  price
# 0        0          3               122  ...       21          27  13495
# 1        1          3               122  ...       21          27  16500
# 2        2          1               122  ...       19          26  16500
# 3        3          2               164  ...       24          30  13950
# 4        4          2               164  ...       18          22  17450
# ..     ...        ...               ...  ...      ...         ...    ...
# 196    200         -1                95  ...       23          28  16845
# 197    201         -1                95  ...       19          25  19045
# 198    202         -1                95  ...       18          23  21485
# 199    203         -1                95  ...       26          27  22470
# 200    204         -1                95  ...       19          25  22625
#
# [201 rows x 27 columns]

# %%
auto.dtypes
# Out:
# index                  int64
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# Converting from object to appropriate data type

# %%
auto['normalized-losses']=auto['normalized-losses'].astype('int')
auto['peak-rpm']=auto['peak-rpm'].astype('int')
auto['price']=auto['price'].astype('int')
auto['horsepower']=auto['horsepower'].astype('int')

# %%
auto['bore']=auto['bore'].astype('float')
auto['stroke']=auto['stroke'].astype('float')

# %% [markdown]
# Converting from mpg to L/100km

# %%
auto['city-L/100km']=235/auto['city-mpg']
auto['highway-L/100km']=235/auto['highway-mpg']

# %%
auto
# Out:
#      index  symboling  normalized-losses  ...  price city-L/100km highway-L/100km
# 0        0          3                122  ...  13495    11.190476        8.703704
# 1        1          3                122  ...  16500    11.190476        8.703704
# 2        2          1                122  ...  16500    12.368421        9.038462
# 3        3          2                164  ...  13950     9.791667        7.833333
# 4        4          2                164  ...  17450    13.055556       10.681818
# ..     ...        ...                ...  ...    ...          ...             ...
# 196    200         -1                 95  ...  16845    10.217391        8.392857
# 197    201         -1                 95  ...  19045    12.368421        9.400000
# 198    202         -1                 95  ...  21485    13.055556       10.217391
# 199    203         -1                 95  ...  22470     9.038462        8.703704
# ...

# %% [markdown]
# Dropping index column as it is useless

# %%
auto.drop("index",axis=1,inplace=True)
auto
# Out:
#      symboling  normalized-losses  ... city-L/100km highway-L/100km
# 0            3                122  ...    11.190476        8.703704
# 1            3                122  ...    11.190476        8.703704
# 2            1                122  ...    12.368421        9.038462
# 3            2                164  ...     9.791667        7.833333
# 4            2                164  ...    13.055556       10.681818
# ..         ...                ...  ...          ...             ...
# 196         -1                 95  ...    10.217391        8.392857
# 197         -1                 95  ...    12.368421        9.400000
# 198         -1                 95  ...    13.055556       10.217391
# 199         -1                 95  ...     9.038462        8.703704
# 200         -1                 95  ...    12.368421        9.400000
#
# [201 rows x 28 columns]

# %% [markdown]
# Normalizing columns

# %%
auto['length']=auto['length']/auto['length'].max()  
auto['width']=auto['width']/auto['width'].max()
auto['height']=auto['height']/auto['height'].max()
auto
# Out:
#      symboling  normalized-losses  ... city-L/100km highway-L/100km
# 0            3                122  ...    11.190476        8.703704
# 1            3                122  ...    11.190476        8.703704
# 2            1                122  ...    12.368421        9.038462
# 3            2                164  ...     9.791667        7.833333
# 4            2                164  ...    13.055556       10.681818
# ..         ...                ...  ...          ...             ...
# 196         -1                 95  ...    10.217391        8.392857
# 197         -1                 95  ...    12.368421        9.400000
# 198         -1                 95  ...    13.055556       10.217391
# 199         -1                 95  ...     9.038462        8.703704
# 200         -1                 95  ...    12.368421        9.400000
#
# [201 rows x 28 columns]

# %% [markdown]
# Plotting histogram for horsepower

# %%
auto['horsepower'].hist()

# %%
plt.hist(auto['horsepower'])
# Out:
# (array([44., 45., 48., 24., 14., 16.,  5.,  4.,  0.,  1.]),
#  array([ 48. ,  69.4,  90.8, 112.2, 133.6, 155. , 176.4, 197.8, 219.2,
#         240.6, 262. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Distributing horsepower into three categories Low,Medium,High

# %%
plt.hist(auto['horsepower'])
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("Horsepower bins")
plt.show()

# %%
print("Min",auto['horsepower'].min())
print("Max",auto['horsepower'].max())
# Out:
# Min 48
# Max 262

# %%
bins=np.linspace(auto['horsepower'].min(),auto['horsepower'].max(),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names=['Low','Medium','High']

# %%
auto['horsepower-binned']=pd.cut(auto['horsepower'],bins=bins,labels=group_names,include_lowest=True)

# %%
auto['horsepower-binned'].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %% [markdown]
# Plotting Histogram after binning horsepower

# %%
plt.bar(group_names,auto['horsepower-binned'].value_counts())
plt.xlabel("Horsepower")
plt.ylabel("count")
plt.title("Horsepower-Bins")
plt.show()

# %% [markdown]
# One Hot encoding 'fuel-type' and 'aspiration'

# %%
onehot1=pd.get_dummies(auto['fuel-type'])
onehot1
onehot2=pd.get_dummies(auto['aspiration'])
onehot2
# Out:
#      std  turbo
# 0      1      0
# 1      1      0
# 2      1      0
# 3      1      0
# 4      1      0
# ..   ...    ...
# 196    1      0
# 197    0      1
# 198    1      0
# 199    0      1
# 200    0      1
#
# [201 rows x 2 columns]

# %% [markdown]
# Joining the one hot encoded columns with dataset

# %%
auto=auto.join(onehot1)
auto=auto.join(onehot2)

# %% [markdown]
# Dropping 'fuel-type' and 'aspiration'

# %%
auto.drop('fuel-type',axis=1,inplace=True)
auto.drop('aspiration',axis=1,inplace=True)

# %% [markdown]
# Final view of the dataset

# %%
auto
# Out:
#      symboling  normalized-losses         make  ... gas std turbo
# 0            3                122  alfa-romero  ...   1   1     0
# 1            3                122  alfa-romero  ...   1   1     0
# 2            1                122  alfa-romero  ...   1   1     0
# 3            2                164         audi  ...   1   1     0
# 4            2                164         audi  ...   1   1     0
# ..         ...                ...          ...  ...  ..  ..   ...
# 196         -1                 95        volvo  ...   1   1     0
# 197         -1                 95        volvo  ...   1   0     1
# 198         -1                 95        volvo  ...   1   1     0
# 199         -1                 95        volvo  ...   0   0     1
# 200         -1                 95        volvo  ...   1   0     1
#
# [201 rows x 31 columns]
